# %% [markdown]
# Implement pow(x, n), which calculates x raised to the power n (xn).
#
#     Example 1:
#
#     Input: 2.00000, 10
#     Output: 1024.00000
#
#     Example 2:
#
#     Input: 2.10000, 3
#     Output: 9.26100
#
#     Example 3:
#
#     Input: 2.00000, -2
#     Output: 0.25000
#     Explanation: 2-2 = 1/22 = 1/4 = 0.25
#
# Note:
#
#     -100.0 < x < 100.0
#
#     n is a 32-bit signed integer, within the range [−2^31, 2^31 − 1]
#
# [Exponention By Power](https://en.wikipedia.org/wiki/Exponentiation_by_squaring)

# %%
def myPow(x,n): 
    if n == 0: return 1
    if n < 0 : return myPow(1/x, -n )
    if n == 1 : return x
    if n % 2 == 0:
        return myPow(x * x, n//2 )
    else:
        return x * myPow(x * x, (n-1)//2)

for i in range(100):
    x,n = random.randint(1,10), random.randint(-10,10)
    res = myPow(x,n)
    print(str(x) + "^" + str(n) + " = " + str(res))
# Out:
# 4^-1 = 0.25
# 10^5 = 100000
# 6^-6 = 2.143347050754458e-05
# 8^8 = 16777216
# 2^2 = 4
# 9^-8 = 2.3230573125418767e-08
# 6^3 = 216
# 1^9 = 1
# 2^1 = 2
# 1^1 = 1
# 6^-6 = 2.143347050754458e-05
# 2^-4 = 0.0625
# 5^9 = 1953125
# 1^-8 = 1.0
# 8^3 = 512
# 5^8 = 390625
# 6^-7 = 3.572245084590763e-06
# 9^7 = 4782969
# 3^7 = 2187
# 9^-8 = 2.3230573125418767e-08
# 10^0 = 1
# 6^-7 = 3.572245084590763e-06
# 1^3 = 1
# 9^-8 = 2.3230573125418767e-08
# 7^-7 = 1.214265678902012e-06
# 4^-4 = 0.00390625
# 8^-5 = 3.0517578125e-05
# 9^1 = 9
# 3^0 = 1
# 8^-9 = 7.450580596923828e-09
# 1^-6 = 1.0
# 4^4 = 256
# 10^-3 = 0.0010000000000000002
# 3^-7 = 0.00045724737082761767
# 9^6 = 531441
# 1^5 = 1
# 8^-6 = 3.814697265625e-06
# 2^-9 = 0.001953125
# 5^10 = 9765625
# 2^-3 = 0.125
# 7^-4 = 0.00041649312786339016
# 3^5 = 243
# 6^0 = 1
# 1^1 = 1
# 4^-9 = 3.814697265625e-06
# 1^0 = 1
# 1^-6 = 1.0
# 8^8 = 16777216
# 4^-5 = 0.0009765625
# 6^2 = 36
# 1^3 = 1
# 9^-4 = 0.00015241579027587256
# 5^8 = 390625
# 8^-8 = 5.960464477539063e-08
# 1^-10 = 1.0
# 5^0 = 1
# 4^-4 = 0.00390625
# 7^-9 = 2.4780932222490035e-08
# 8^6 = 262144
# 6^-2 = 0.027777777777777776
# 8^-8 = 5.960464477539063e-08
# 3^10 = 59049
# 6^0 = 1
# 3^-3 = 0.037037037037037035
# 2^-8 = 0.00390625
# 10^0 = 1
# 1^-6 = 1.0
# 7^-6 = 8.499859752314083e-06
# 2^9 = 512
# 9^9 = 387420489
# 6^6 = 46656
# 1^-5 = 1.0
# 4^-1 = 0.25
# 7^5 = 16807
# 2^-3 = 0.125
# 6^6 = 46656
# 10^4 = 10000
# 9^7 = 4782969
# 4^1 = 4
# 7^6 = 117649
# 8^2 = 64
# 8^-3 = 0.001953125
# 1^-6 = 1.0
# 10^-6 = 1.0000000000000006e-06
# 3^2 = 9
# 2^7 = 128
# 7^2 = 49
# 4^-10 = 9.5367431640625e-07
# 1^-1 = 1.0
# 3^-4 = 0.012345679012345678
# 7^0 = 1
# 6^1 = 6
# 1^-3 = 1.0
# 10^-3 = 0.0010000000000000002
# 5^-9 = 5.120000000000005e-07
# 7^7 = 823543
# 10^2 = 100
# 7^10 = 282475249
# 8^4 = 4096
# 3^7 = 2187

# %%
import random

# %%
??random
