# %% [markdown]
# Implement pow(x, n), which calculates x raised to the power n (xn).
#
#     Example 1:
#
#     Input: 2.00000, 10
#     Output: 1024.00000
#
#     Example 2:
#
#     Input: 2.10000, 3
#     Output: 9.26100
#
#     Example 3:
#
#     Input: 2.00000, -2
#     Output: 0.25000
#     Explanation: 2-2 = 1/22 = 1/4 = 0.25
#
# Note:
#
#     -100.0 < x < 100.0
#
#     n is a 32-bit signed integer, within the range [−2^31, 2^31 − 1]
#
# [Exponention By Power](https://en.wikipedia.org/wiki/Exponentiation_by_squaring)

# %%
import random
def myPow(x,n): 
    if n == 0: return 1
    if n < 0 : return myPow(1/x, -n )
    if n == 1 : return x
    if n % 2 == 0:
        return myPow(x * x, n//2 )
    else:
        return x * myPow(x * x, (n-1)//2)

for i in range(100):
    x,n = random.randint(1,10), random.randint(-10,10)
    res = myPow(x,n)
    print(str(x) + "^" + str(n) + " = " + str(res))
# Out:
# 10^2 = 100
# 2^-8 = 0.00390625
# 8^1 = 8
# 3^8 = 6561
# 5^2 = 25
# 3^-8 = 0.00015241579027587256
# 7^0 = 1
# 2^-1 = 0.5
# 4^5 = 1024
# 6^7 = 279936
# 1^-10 = 1.0
# 5^-7 = 1.2800000000000008e-05
# 5^5 = 3125
# 10^-5 = 1.0000000000000006e-05
# 8^-1 = 0.125
# 7^5 = 16807
# 10^-2 = 0.010000000000000002
# 7^9 = 40353607
# 4^8 = 65536
# 4^-10 = 9.5367431640625e-07
# 4^9 = 262144
# 5^1 = 5
# 4^3 = 64
# 9^-3 = 0.0013717421124828531
# 6^1 = 6
# 9^0 = 1
# 7^-7 = 1.214265678902012e-06
# 3^4 = 81
# 7^2 = 49
# 1^1 = 1
# 4^-2 = 0.0625
# 9^0 = 1
# 7^4 = 2401
# 10^-8 = 1.0000000000000008e-08
# 9^-10 = 2.8679719907924403e-10
# 5^1 = 5
# 2^-3 = 0.125
# 7^8 = 5764801
# 5^4 = 625
# 4^3 = 64
# 10^-8 = 1.0000000000000008e-08
# 4^-8 = 1.52587890625e-05
# 1^-4 = 1.0
# 9^6 = 531441
# 3^0 = 1
# 9^-9 = 2.5811747917131962e-09
# 4^-2 = 0.0625
# 8^9 = 134217728
# 8^0 = 1
# 6^-9 = 9.922903012752119e-08
# 8^-2 = 0.015625
# 6^3 = 216
# 10^0 = 1
# 1^-7 = 1.0
# 5^-7 = 1.2800000000000008e-05
# 4^-4 = 0.00390625
# 5^-7 = 1.2800000000000008e-05
# 6^-8 = 5.953741807651272e-07
# 4^-4 = 0.00390625
# 7^-10 = 3.5401331746414338e-09
# 7^0 = 1
# 4^0 = 1
# 2^10 = 1024
# 8^5 = 32768
# 8^-10 = 9.313225746154785e-10
# 4^2 = 16
# 7^-3 = 0.0029154518950437313
# 8^1 = 8
# 1^5 = 1
# 4^-2 = 0.0625
# 1^-7 = 1.0
# 10^0 = 1
# 6^-3 = 0.004629629629629629
# 9^3 = 729
# 6^-8 = 5.953741807651272e-07
# 6^8 = 1679616
# 1^-9 = 1.0
# 10^9 = 1000000000
# 2^6 = 64
# 3^2 = 9
# 6^7 = 279936
# 10^9 = 1000000000
# 5^-10 = 1.0240000000000011e-07
# 5^-8 = 2.560000000000002e-06
# 10^-10 = 1.0000000000000011e-10
# 1^-2 = 1.0
# 2^-6 = 0.015625
# 5^-9 = 5.120000000000005e-07
# 1^8 = 1
# 3^0 = 1
# 7^-2 = 0.02040816326530612
# 5^7 = 78125
# 10^0 = 1
# 9^-4 = 0.00015241579027587256
# 6^5 = 7776
# 5^-2 = 0.04000000000000001
# 10^-10 = 1.0000000000000011e-10
# 10^-4 = 0.00010000000000000005
# 8^-4 = 0.000244140625
# 6^4 = 1296

# %%
??random
